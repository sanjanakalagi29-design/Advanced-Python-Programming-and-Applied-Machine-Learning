# %%
print("Hello world");
# Out:
# Hello world

# %%
print("*"*3)
# Out:
# ***

# %%
print("*"*4)
# Out:
# ****

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
print("*" * 3,sep="\n")
# Out:
# ***

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
Name="Sanjana"
print(Name)
# Out:
# Sanjana
